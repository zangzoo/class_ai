# %% [markdown]
# <a href="https://colab.research.google.com/github/jihoo420/class_ai/blob/main/9_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#데이터프레임 만들기

import pandas as pd

df= pd.DataFrame([
    {'이름':'박지후','학과':'응용통계학과','국적':'한국'},
    {'이름':'김상욱','학과':'응용통계학과','국적':'한국'},
    {'이름':'유지원','학과':'심리학과','국적':'한국'},
    {'이름':'류혜영','학과':'영어영문학과','국적':'한국'},
    {'이름':'이민주','학과':'경영학과','국적':'한국'}])
df
# Out:
#     이름      학과  국적
# 0  박지후  응용통계학과  한국
# 1  김상욱  응용통계학과  한국
# 2  유지원    심리학과  한국
# 3  류혜영  영어영문학과  한국
# 4  이민주    경영학과  한국

# %%
#index 지정
df.index=['1번','2번','3번','4번','5번']
df
# Out:
#      이름      학과  국적
# 1번  박지후  응용통계학과  한국
# 2번  김상욱  응용통계학과  한국
# 3번  유지원    심리학과  한국
# 4번  류혜영  영어영문학과  한국
# 5번  이민주    경영학과  한국

# %%
#csv로 내보내기
file_path = "자기소개.csv"
df.to_csv(file_path, index=False)

# %%
#csv파일 불러오기
df1 = pd.read_csv('자기소개.csv')
df1
# Out:
#     이름      학과  국적
# 0  박지후  응용통계학과  한국
# 1  김상욱  응용통계학과  한국
# 2  유지원    심리학과  한국
# 3  류혜영  영어영문학과  한국
# 4  이민주    경영학과  한국
